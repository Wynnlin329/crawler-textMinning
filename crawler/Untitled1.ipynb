# %%
from selenium import webdriver

# %%
driver_article = webdriver.Chrome('./chromedriver')
driver_article.get('https://www.instagram.com/p/B3rFLePHvam/')

# %%
import time

# %%
length = len(driver.find_elements_by_class_name('_-1_m6'))
for rr in range(length):

    try:
        pic = driver.find_elements_by_class_name('_-1_m6')[rr]
        print(pic.find_elements_by_class_name('FFVAD')[0].get_attribute('src'))
#         print(type())
        driver.find_elements_by_class_name('_6CZji')[0].click()
        if rr == length-1:
            pic = driver.find_elements_by_class_name('_-1_m6')[rr]
            print(pic.find_elements_by_class_name('FFVAD')[0].get_attribute('src'))
    except Exception as e:
        print(e)
        break
#     print('右點')
    time.sleep(1)
#     cc = driver.find_elements_by_class_name('FFVAD')
#     cc = driver.find_elements_by_class_name('_-1_m6')
#     print(len(cc))
# pic = x.get_attribute('src').split(',')[-1][:-4]
# Out:
# https://instagram.ftpe7-1.fna.fbcdn.net/vp/1c56fbea24dc716b954a66938a9c9056/5E48DF56/t51.2885-15/e35/s1080x1080/70911384_764781453954394_5517222971014425997_n.jpg?_nc_ht=instagram.ftpe7-1.fna.fbcdn.net&_nc_cat=110
# https://instagram.ftpe7-1.fna.fbcdn.net/vp/8342c528d3c1a25fcd935b2e1b4f6729/5E414B74/t51.2885-15/e35/s1080x1080/71143981_426699024646944_7770687772108602770_n.jpg?_nc_ht=instagram.ftpe7-1.fna.fbcdn.net&_nc_cat=100
# https://instagram.ftpe7-1.fna.fbcdn.net/vp/2849a9b41390ce8fa704953b8af97318/5E629131/t51.2885-15/e35/s1080x1080/72147109_513406315906354_7152723408332646311_n.jpg?_nc_ht=instagram.ftpe7-1.fna.fbcdn.net&_nc_cat=110
# https://instagram.ftpe7-3.fna.fbcdn.net/vp/af6e6aa79b28f9832deffbe7e5b7224e/5E626A15/t51.2885-15/e35/s1080x1080/70846962_402154960716086_8978461721273958683_n.jpg?_nc_ht=instagram.ftpe7-3.fna.fbcdn.net&_nc_cat=102
# ...

# %%
length = len(driver_article.find_elements_by_class_name('_-1_m6'))
print(length)
pic_list = []
for rr in range(length):

    try:
        p = driver_article.find_elements_by_class_name('_-1_m6')[rr]
        pic = p.find_elements_by_class_name('FFVAD')[0].get_attribute('src')
        pic_list.append(pic)
        driver_article.find_elements_by_class_name('_6CZji')[0].click()
#         if rr == length - 1:
#             print('hi')
#             p = driver_article.find_elements_by_class_name('_-1_m6')[rr]
#             pic = p.find_elements_by_class_name('FFVAD')[0].get_attribute('src')
#             pic_list.append(pic)
    except Exception as e:
        print(e)
        break
    #     print('右點')
#     pic_list.append(pic)
    time.sleep(1)
# Out:
# 5
# list index out of range

# %%
pic_list
# Out:
# ['https://scontent-hkg3-1.cdninstagram.com/vp/262f10e19ee7b45c7c345a7d9d8e45c9/5E48DF56/t51.2885-15/e35/s1080x1080/70911384_764781453954394_5517222971014425997_n.jpg?_nc_ht=scontent-hkg3-1.cdninstagram.com&_nc_cat=110',
#  'https://scontent-hkg3-1.cdninstagram.com/vp/3a912141bfe8f64e3add677995d2aa19/5E414B74/t51.2885-15/e35/s1080x1080/71143981_426699024646944_7770687772108602770_n.jpg?_nc_ht=scontent-hkg3-1.cdninstagram.com&_nc_cat=100',
#  'https://scontent-hkg3-1.cdninstagram.com/vp/3aac67da7934c0f4f8a3da736104eaff/5E629131/t51.2885-15/e35/s1080x1080/72147109_513406315906354_7152723408332646311_n.jpg?_nc_ht=scontent-hkg3-1.cdninstagram.com&_nc_cat=110',
#  'https://scontent-hkg3-1.cdninstagram.com/vp/a2c17198003d9ef3a99542e65e75eaa3/5E626A15/t51.2885-15/e35/s1080x1080/70846962_402154960716086_8978461721273958683_n.jpg?_nc_ht=scontent-hkg3-1.cdninstagram.com&_nc_cat=102',
# ...

# %%
# !pip freeze all
# Out:
# absl-py==0.8.0
# alabaster==0.7.12
# anaconda-client==1.7.2
# anaconda-navigator==1.9.7
# anaconda-project==0.8.3
# asn1crypto==0.24.0
# astor==0.8.0
# astroid==2.2.5
# astropy==3.2.1
# atomicwrites==1.3.0
# attrs==19.1.0
# Babel==2.7.0
# backcall==0.1.0
# backports.functools-lru-cache==1.5
# backports.os==0.1.1
# backports.shutil-get-terminal-size==1.0.0
# backports.tempfile==1.0
# backports.weakref==1.0.post1
# beautifulsoup4==4.7.1
# bitarray==0.9.3
# bkcharts==0.2
# bleach==3.1.0
# bokeh==1.2.0
# boto==2.49.0
# Bottleneck==1.2.1
# certifi==2019.6.16
# cffi==1.12.3
# chardet==3.0.4
# Click==7.0
# cloudpickle==1.2.1
# clyent==1.2.2
# colorama==0.4.1
# comtypes==1.1.7
# conda==4.7.12
# conda-build==3.18.8
# conda-package-handling==1.3.11
# conda-verify==3.4.2
# contextlib2==0.5.5
# cryptography==2.7
# cycler==0.10.0
# Cython==0.29.12
# cytoolz==0.10.0
# dask==2.1.0
# decorator==4.4.0
# defusedxml==0.6.0
# dfply==0.3.3
# distributed==2.1.0
# Django==2.2.6
# docutils==0.14
# ...

# %%
print('https://scontent-hkg3-1.cdninstagram.com/vp/3fcda495e5870c2e9afb69552cbbcdd3/5E538BF3/t51.2885-15/sh0.08/e35/s750x750/73457422_154743809074977_6381612185591554165_n.jpg?_nc_ht=scontent-hkg3-1.cdninstagram.com&_nc_cat=109')
# Out:
# https://scontent-hkg3-1.cdninstagram.com/vp/3fcda495e5870c2e9afb69552cbbcdd3/5E538BF3/t51.2885-15/sh0.08/e35/s750x750/73457422_154743809074977_6381612185591554165_n.jpg?_nc_ht=scontent-hkg3-1.cdninstagram.com&_nc_cat=109
