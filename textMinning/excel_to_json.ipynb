# %%
import pandas as pd
import json
import numpy as np

# %%
path = './VOGUEblog'
pd.read_excel(r'./VOGUEblog/VOGUEblog.xlsx')
TT_cut.to_json(path+'/VOGUEblog.json',orient='index')#轉JSON
# Out:
#       Unnamed: 0                                                 標題  \
# 0              0     【MISSHA唇彩】VIDEOᴴᴰ미샤MISSHA韓國新品唇釉口紅唇彩開箱試色｜AiNa愛娜
# 1              1              『韓國彩妝』還在煩惱毛孔眼袋暗沈嗎？全新升級二奶霜氣墊粉餅ㄧ拍就完妝出門！
# 2              2            唇彩｜LOREALPARIS巴黎萊雅持色印記空氣吻唇露#129(主導)試色分享
# 3              3           【美妝】黑色皮革壓紋好美！L'OrealParis巴黎萊雅純色訂製唇膏柔霧款試色
# 4              4     【MISSHA唇彩】VIDEOᴴᴰ미샤MISSHA韓國新品唇釉口紅唇彩開箱試色｜AiNa愛娜
# 5              5              『韓國彩妝』還在煩惱毛孔眼袋暗沈嗎？全新升級二奶霜氣墊粉餅ㄧ拍就完妝出門！
# 6              6            唇彩｜LOREALPARIS巴黎萊雅持色印記空氣吻唇露#129(主導)試色分享
# 7              7           【美妝】黑色皮革壓紋好美！L'OrealParis巴黎萊雅純色訂製唇膏柔霧款試色
# 8              8                       [影]日常紅唇妝容｜DailyRedLipsMakeup
# 9              9         [影]秋天焦橙日落妝容｜FallCaramelOrangeXSunsetMakeup
# 10            10                                【粉底衣櫃】無法抉擇的生火粉底神隊友❤
# 11            11       【迷唇姊】秒殺法式特調x香奈兒超炫耀絲絨唇露新色❤半熟果漿色#226ROMANTIQUE
# 12            12                【迷唇姊】雅詩蘭黛經典防呆絕美色#420玫瑰荔枝❤超生火限定玫瑰金包裝
# ...

# %%
pd.read_json(r'./DATA/FGblog.json',orient  = 'index')
# Out:
#                                 作者  \
# 0                    韓妞-金老佛爺 愛玩美世界
# 1                    ♥萍果♥吃喝玩樂的幸福生活
# 2                            仙女送公文
# 3                           wenjie
# 4                             保鮮美人
# 5                            愛美不打烊
# 6                            160女子
# 7                            160女子
# 8             諾薇亞Novia—誰說部落客不說真心話—
# 9                         小婷懶骨頭記事~
# 10                       柯蘿依Chloe♥
# 11                         靖妹❈愛保養
# 12                           愛美不打烊
# 13                           愛美不打烊
# 14                           愛美不打烊
# 15                           愛美不打烊
# 16            諾薇亞Novia—誰說部落客不說真心話—
# 17                          瑞秋兒愛分享
# 18                    Elvira。艾小猴是我
# 19               OnLyYuSuKe吃喝玩樂都最高
# 20                         時間把習慣換了
# 21                         茱莉的玩美生活
# 22                            保鮮美人
# 23    SARAH │ food+feeling=Fooding
# 24                         茱莉的玩美生活
# ...

# %%
TT_cut = TT_json.drop(columns = ['Unnamed: 0'],axis=1)
TT_cut
# Out:
#                          作者  \
# 0              台韓混血 AiNa 愛娜
# 1                    LinsaW
# 2                  柯蘿依Chloe
# 3                      Tong
# 4              台韓混血 AiNa 愛娜
# 5                    LinsaW
# 6                  柯蘿依Chloe
# 7                      Tong
# 8                  Angelica
# 9                  Angelica
# 10                       大魚
# 11                       大魚
# 12                       大魚
# 13                 Angelica
# 14              Jamie 的娘娘生活
# 15                 柯蘿依Chloe
# 16          MultiplisMakeup
# 17                       名辰
# 18                       大魚
# 19                       大魚
# 20                       大魚
# 21                       大魚
# 22                       大魚
# 23                       大魚
# 24              Jamie 的娘娘生活
# 25                       大魚
# 26                       大魚
# 27                   Syrena
# 28                       大魚
# 29                 柯蘿依Chloe
# ...                     ...
# 2939               FACY 編輯部
# ...

# %%
df.to_excel(path+'\\FGblog.xlsx',encoding='utf-16')

# %%
TT_cut
# Out:
#                          作者  \
# 0              台韓混血 AiNa 愛娜
# 1                    LinsaW
# 2                  柯蘿依Chloe
# 3                      Tong
# 4              台韓混血 AiNa 愛娜
# 5                    LinsaW
# 6                  柯蘿依Chloe
# 7                      Tong
# 8                  Angelica
# 9                  Angelica
# 10                       大魚
# 11                       大魚
# 12                       大魚
# 13                 Angelica
# 14              Jamie 的娘娘生活
# 15                 柯蘿依Chloe
# 16          MultiplisMakeup
# 17                       名辰
# 18                       大魚
# 19                       大魚
# 20                       大魚
# 21                       大魚
# 22                       大魚
# 23                       大魚
# 24              Jamie 的娘娘生活
# 25                       大魚
# 26                       大魚
# 27                   Syrena
# 28                       大魚
# 29                 柯蘿依Chloe
# ...                     ...
# 2939               FACY 編輯部
# ...

# %%
TT_cut.groupby('作者').
# Out:
#                                                                               日期  \
# 作者
# A-SQUARE 次方髮藝         CHEETAH  Aug 16 - 2019Sep 26 - 2019Aug 16 - 2019Sep 26 ...
# AB                             Jul 03 - 2018Mar 30 - 2018Mar 26 - 2018Mar 12 ...
# Angelica                       Oct 07 - 2019Sep 24 - 2019Sep 15 - 2019Jun 15 ...
# Barbie Chu                     May 05 - 2017Apr 12 - 2017Mar 17 - 2017Mar 14 ...
# Bonita邦尼                       Jul 27 - 2018Apr 25 - 2018Mar 31 - 2018Dec 30 ...
# Bonnie                         Feb 11 - 2019Nov 13 - 2018Feb 11 - 2019Nov 13 ...
# Caterina Ciao                  Mar 19 - 2018Jan 28 - 2018Jan 14 - 2018Oct 30 ...
# Ching Hs.                      Sep 08 - 2018Aug 06 - 2018Apr 23 - 2018Mar 26 ...
# Christine Lin                  Dec 27 - 2017Nov 10 - 2017Sep 27 - 2017Aug 28 ...
# Core                           Jun 21 - 2017Jun 12 - 2017Jun 01 - 2017Apr 08 ...
# ...

# %%
df = pd.DataFrame({'temp_c': [17.0, 25.0]},index=['Portland', 'Berkeley'])
df
# Out:
#           temp_c
# Portland    17.0
# Berkeley    25.0

# %%
df.assign(temp_f=lambda x: x.temp_c * 9 / 5 + 32)
# Out:
#           temp_c  temp_f
# Portland    17.0    62.6
# Berkeley    25.0    77.0
